# %% [markdown]
# # Miscellaneous Special Relativity
# Bill Gabella 20181113

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
import SpecialRelativity as sr # Lots of coordinate handling, toward the twin and triplet problem.

# %%
aboo = sr.boost(0.33)

# %%
sr.boost(1.1)
# Out:
# ***ERROR in SpecialRelativity.boost, beta is 1.100 .
# array([[1., 0.],
#        [0., 1.]])

# %%
sigma3 = np.array( [ [1, 0], [0, -1] ] )
ident2 = np.diag([1,1])
print(sigma3,'\n', ident2)
# Out:
# [[ 1  0]
#  [ 0 -1]]
#  [[1 0]
#  [0 1]]

# %%
aboo.transpose()*sigma3*aboo
# Out:
# array([[ 1.12220851,  0.        ],
#        [ 0.        , -1.12220851]])

# %%
np.linalg.inv(aboo)*aboo
# Out:
# array([[ 1.12220851, -0.12220851],
#        [-0.12220851,  1.12220851]])

# %%
mySprime = sr.txgrid( 0.5 )

# %%
(afig, aax) = mySprime.grid()

# %%
aax.grid(True)

# %%
mySprime = sr.txgrid( 0.9 )
(afig, aax) = mySprime.grid()

# %%
mySprime = sr.txgrid( 0.05 )
(afig, aax) = mySprime.grid()

# %%
mySprime = sr.txgrid( -0.5 )
(afig, aax) = mySprime.grid()
